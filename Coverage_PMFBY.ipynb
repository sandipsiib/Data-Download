# %% [markdown]
# <a href="https://colab.research.google.com/github/aksoni859/PMFBY_Portal/blob/main/Coverage_PMFBY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import urllib
import json
from datetime import datetime,date
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_master = pd.read_excel("/content/drive/MyDrive/MRIB/Aurangabad.xlsx",dtype=str)

# %%
all_data = []
for index, row in data_master.iterrows():
  print(i,row['villageName'])
  levelCode = row['level6Code']
  level_5_code = row['level5Code']
  level_3_code = row['districtCode']
  level_4_code = row['level4Code']
  url = "https://pmfby.gov.in/goiConfig/getAdminDashboardLevelCoverageReport?schemeCode=04&stateCode=27&year=2021&seasonCode=02&"+ \
        "levelNo=6&levelCode="+str(levelCode)+"&level_5_code="+str(level_5_code)+"&level_3_code="+str(level_3_code)+"&level_4_code="+str(level_4_code)
  print(url)
  
  r1=requests.get(url=url)
  data_json = json.loads(r1.content)

  for data in data_json['data']:
    all_data.append(data)

df_data = pd.DataFrame(all_data)
df_data.to_excel("Aurangabad_Vill_Premium_Rabi2021.xlsx")
# Out:
# 25 Wanegaon Kh
# https://pmfby.gov.in/goiConfig/getAdminDashboardLevelCoverageReport?schemeCode=04&stateCode=27&year=2021&seasonCode=02&levelNo=6&levelCode=170789&level_5_code=548273&level_3_code=515&level_4_code=04136
# 25 Rahegaon
# https://pmfby.gov.in/goiConfig/getAdminDashboardLevelCoverageReport?schemeCode=04&stateCode=27&year=2021&seasonCode=02&levelNo=6&levelCode=171047&level_5_code=548252&level_3_code=515&level_4_code=04139
# 25 Sultanpur
# https://pmfby.gov.in/goiConfig/getAdminDashboardLevelCoverageReport?schemeCode=04&stateCode=27&year=2021&seasonCode=02&levelNo=6&levelCode=170378&level_5_code=548278&level_3_code=515&level_4_code=04140
# 25 Wadod Kh.
# https://pmfby.gov.in/goiConfig/getAdminDashboardLevelCoverageReport?schemeCode=04&stateCode=27&year=2021&seasonCode=02&levelNo=6&levelCode=170784&level_5_code=548285&level_3_code=515&level_4_code=04136
# 25 Dalwadi
# ...

# %%
df_data1 = df_data.drop_duplicates()

# %%
df_data1.to_excel("Aurangabad_Vill_Premium_Rabi2021_drop_duplicates.xlsx")
